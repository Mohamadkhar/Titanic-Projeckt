# %% [markdown]
# # Python and CLI for Data Science - Session 09
#
# - *Course*: Python and CLI for Data Science
# - *Session*: 09
# - *Unit*: Matplotlib Introduction

# %% [markdown]
# ### (Re)sources:
# - [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html) _by Jake VanderPlas (Code released under the MIT License)_

# %% [markdown]
# ## Visualization with Matplotlib
#
# - Matplotlib is a data visualization library built on NumPy with a wide user base

# %% [markdown]
# ## Importing Matplotlib
#
# - We will use some standard shorthands for Matplotlib imports
# - Matplotlib's `plt` interface is all you need in 99% of cases

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## show or No show? How to Display Your Plots
#
# - We will go over two possibilities for displaying plots with Matplotlib:
#     - in a script
#     - in a Jupyter notebook

# %% [markdown]
# ### Plotting from a Script
#
# - If you are using Matplotlib from within a script, the function `plt.show` is your friend
# - `plt.show` starts an event loop, looks for all currently active `Figure` objects, and opens one or more interactive windows that display your figure or figures

# %% [markdown]
# - So, for example, you may have a file called *myplot.py* containing the following:
#
# ```python
# # file: myplot.py
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(0, 10, 100)
#
# plt.plot(x, np.sin(x))
# plt.plot(x, np.cos(x))
#
# plt.show()
# ```

# %% [markdown]
# - You can then run this script from the command-line prompt, which will result in a window opening with your figure displayed
#
# ```
# $ python myplot.py
# ```

# %% [markdown]
# - The `plt.show` command interacts with your system's interactive graphical backend
# > `plt.show` should be used *only once* per Python session
# - Matplotlib does its best to hide all system-specific and implementation-specific details from you

# %%
# %%writefile myplot.py
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %% [markdown]
# ### Plotting from a Jupyter Notebook
#
# - Plotting interactively within a Jupyter notebook can be done with the `%matplotlib` magic command
# - You have two possible options:
#     - `%matplotlib inline` will lead to *static* images of your plot embedded in the notebook
#     - `%matplotlib notebook` will lead to *interactive* plots embedded within the notebook

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), "-")
plt.plot(x, np.cos(x), "--")

# %% [markdown]
# ### Saving Figures to File
#
# - One nice feature of Matplotlib is the ability to save figures in a wide variety of formats
# - Saving a figure can be done using the `savefig` command
# - For example, to save the previous figure as a PNG file, we can run this

# %%
fig.savefig("my_figure.png")

# %% [markdown]
# - We now have a file called *my_figure.png* in the current working directory

# %%
# !ls -lh my_figure.png

# %% [markdown]
# - To confirm that it contains what we think it contains, let's use the IPython `Image` object to display the contents of this file

# %%
from IPython.display import Image

Image("my_figure.png")

# %% [markdown]
# - In `savefig`, the file format is inferred from the extension of the given filename
# - Depending on what backends you have installed, many different file formats are available

# %%
fig.canvas.get_supported_filetypes()

# %% [markdown]
# ### Two Interfaces for the Price of One
#
# - A potentially confusing feature of Matplotlib is its dual interfaces
#     - One convenient MATLAB-style state-based interface
#     - One more powerful object-oriented interface

# %% [markdown]
# #### MATLAB-style Interface
#
# - Matplotlib was originally conceived as a Python alternative for MATLAB users
# - Much of matplotlib's syntax reflects this fact
# - The MATLAB-style tools are contained in the `pyplot` (`plt`) interface

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1)  # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# - It is important to recognize that this interface is *stateful*:
#
# > All `plt` commands are applied to a "current" figure and axes

# %% [markdown]
# - While this stateful interface is fast and convenient for simple plots, it is easy to run into problems
# - For example, once the second panel is created, how can we go back and add something to the first?
# - This is possible within the MATLAB-style interface, but a bit clunky

# %% [markdown]
# #### Object-oriented interface
#
# - The object-oriented interface is available for when you want more control over your figure
# - In the object-oriented interface the plotting functions are *methods* of explicit `Figure` and `Axes` objects

# %%
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2) # previously we used plt.subplot (without `s`)

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# - For simpler plots, the choice of which style to use is largely a matter of preference
# - The object-oriented approach can become a necessity as plots become more complicated

# %% [markdown]
# - We will switch between the MATLAB-style and object-oriented interfaces, depending on what is most convenient
# - In most cases, the difference is as small as switching `plt.plot` to `ax.plot`
# - However, there can be minor differences and it is important to be aware of this fact

# %% [markdown]
# ## Figure and Axes Objects
#
# - For all Matplotlib plots, we start by creating a figure and axes
# - In their simplest form, this can be done as follows

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# - In Matplotlib, the *figure* (an instance of the class `plt.Figure`) can be thought of as a single container that contains all the objects
# - The *axes* (an instance of the class `plt.Axes`) is what we see above: a bounding box with ticks, grids, and labels, which will eventually contain the plot elements that make up our visualization

# %% [markdown]
# - Once we have created an axes, we can use the `ax.plot` method to plot some data

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x))

# %% [markdown]
# ## Adjusting the Plot
#
# - After plotting data we may want to modify the plot and add additional context
# - Next, we will go through a few common examples of how to modify and label a plot

# %% [markdown]
# ### Axes Limits
#
# - Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control
# - The most basic way to adjust the limits is to use the `plt.xlim` and `plt.ylim` functions

# %%
plt.plot(x, np.sin(x)) # now using the MATLAB-style interface

plt.xlim(-1, 5)
plt.ylim(-1.5, 0.5)

# %% [markdown]
# ### Labels
#
# - It is also good practice to label the x-axis, y-axis, and to add a title to clarify what data is being visualized
# - Matplotlib offers more options for labels, but adding these basic labels is as easy as calling the respective methods

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")

# %% [markdown]
# ### Legend
#
# - When plotting multiple items, it can be helpful to label the items and to add a legend
# - Matplotlib has a built-in way of quickly creating a legend; it is done via the `plt.legend` method

# %%
plt.plot(x, np.sin(x), "-g", label="sin(x)")
plt.plot(x, np.cos(x), ":b", label="cos(x)")

plt.legend()

# %% [markdown]
# ## Matplotlib Gotchas
#
# - While most `plt` functions translate directly to `ax` methods (`plt.plot` → `ax.plot`, `plt.legend` → `ax.legend`, etc.), this is not the case for all commands
# - In particular, functions to set limits, labels, and titles are slightly modified

# %% [markdown]
# - For transitioning between MATLAB-style functions and object-oriented methods, make the following changes
#
# - `plt.xlabel`  → `ax.set_xlabel`
# - `plt.ylabel` → `ax.set_ylabel`
# - `plt.xlim`  → `ax.set_xlim`
# - `plt.ylim` → `ax.set_ylim`
# - `plt.title` → `ax.set_title`
#
# - In the object-oriented interface to plotting, it is often more convenient to use the `ax.set` method to set all these properties at once

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2), xlabel="x", ylabel="sin(x)", title="A Simple Plot")

# %% [markdown]
# ## Exercise
#
# Plot a unit circle (radius=1). Set the x and y axis limits to -2 to 2. The following code provides the x and y coordinates for a circle.
#
# ```py
# radius = 1
# theta = np.linspace(0, 2 * np.pi, 100)
# x = radius * np.cos(theta)
# y = radius * np.sin(theta)
# ```
#
# By default, the circle looks like an ellipse. Why? Can you fix it?

# %%
# Solve the exercise here

# %%
radius = 1
theta = np.linspace(0, 2 * np.pi, 100)
x = radius * np.cos(theta)
y = radius * np.sin(theta)

# fig, ax = plt.subplots(figsize=(4,4)) # one solution is to modify the figure's size
fig, ax = plt.subplots()
ax.plot(x, y)
# ax.axis("equal") # another is to set the axes to be equally spaced
ax.set(xlim=(-2,2), ylim=(-2,2))
